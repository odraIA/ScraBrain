# %%
import pnpl.datasets as datasets

keywords = ["libri", "armeni", "gwill", "masc", "schoff", "mous"]

for k in keywords:
    found = [name for name in dir(datasets) if k in name.lower()]
    print(k, found)
# Out:
# libri ['LibriBrainCompetitionHoldout', 'LibriBrainPhoneme', 'LibriBrainSpeech', 'LibriBrainWord']
# armeni []
# gwill []
# masc []
# schoff []
# mous []

# %% [markdown]
# Pa copiar cosas

# %% [markdown]
# rsync -avh --progress -e "ssh -p 6167" sherlock_data/ rdiaper@gtirouter.dsic.upv.es:~/proyectos/ScraBrain/sherlock_data/
