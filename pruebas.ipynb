# %%
import pnpl.datasets as datasets

keywords = ["libri", "armeni", "gwill", "masc", "schoff", "mous"]

for k in keywords:
    found = [name for name in dir(datasets) if k in name.lower()]
    print(k, found)
# Out:
# libri ['LibriBrainCompetitionHoldout', 'LibriBrainPhoneme', 'LibriBrainSpeech', 'LibriBrainWord']
# armeni []
# gwill []
# masc []
# schoff []
# mous []

# %% [markdown]
# Pa copiar cosas

# %% [markdown]
# rsync -avh --progress -e "ssh -p 6167" sherlock_data/ rdiaper@gtirouter.dsic.upv.es:~/proyectos/ScraBrain/sherlock_data/

# %% [markdown]
# rclone copy :webdav: ./sherlock_data2   --webdav-url "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1"   --webdav-vendor other   --progress   --transfers 4   --checkers 8   --retries 10   --low-level-retries 20   --timeout 60s   --contimeout 30s

# %% [markdown]
# (scrabrain) odra@odra-vrain:~/GitHub/ScraBrain$ rclone copy :webdav: ./sherlock_data2   --webdav-url "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1"   --webdav-vendor other   --progress   --transfers 4   --checkers 8   --retries 10   --low-level-retries 20   --timeout 60s   --contimeout 30s
# 2026/05/04 19:28:09 NOTICE: Config file "/home/odra/snap/rclone/587/.config/rclone/rclone.conf" not found - using defaults
# 2026/05/04 19:30:25 ERROR : sub-002/ses-007: error reading source directory: couldn't list files: Propfind "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1/sub-002/ses-007/": dial tcp: lookup webdav.data.ru.nl on 127.0.0.53:53: server misbehaving
# 2026/05/04 19:30:26 ERROR : code/pipeline/utilities: error reading source directory: couldn't list files: Propfind "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1/code/pipeline/utilities/": dial tcp: lookup webdav.data.ru.nl on 127.0.0.53:53: server misbehaving
# 2026/05/04 19:30:26 ERROR : sub-002/ses-004/meg: error reading source directory: couldn't list files: Propfind "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1/sub-002/ses-004/meg/": dial tcp: lookup webdav.data.ru.nl on 127.0.0.53:53: server misbehaving
# 2026/05/04 19:30:27 ERROR : sub-003/ses-002/meg/sub-003_ses-002_task-compr_meg.ds/hz.ds: error reading source directory: couldn't list files: Propfind "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1/sub-003/ses-002/meg/sub-003_ses-002_task-compr_meg.ds/hz.ds/": dial tcp: lookup webdav.data.ru.nl on 127.0.0.53:53: server misbehaving
# 2026/05/04 19:30:27 ERROR : sub-001/ses-006/eyelink: error reading source directory: couldn't list files: Propfind "https://webdav.data.ru.nl/dccn/DSC_3011085.05_995_v1/sub-001/ses-006/eyelink/": dial tcp: lookup webdav.data.ru.nl on 127.0.0.53:53: server misbehaving
# Transferred:      298.340 KiB / 214.117 GiB, 0%, 0 B/s, ETA -
# Errors:                 5 (retrying may help)
# Checks:                 0 / 0, -, Listed 2377
# Transferred:            3 / 2143, 0%
# Elapsed time:     16m50.0s
# Transferring:
#  *                      dataset_description.json: transferring
#  *                              participants.tsv: transferring
#  *     sub-003/ses-001/sub-003_ses-001_scans.tsv: transferring
#  *     sub-003/ses-002/sub-003_ses-002_scans.tsv: transferring
